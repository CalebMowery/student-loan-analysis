# %%
import requests
import json
import pandas as pd

# %%
data = requests.get("https://api.data.gov/ed/collegescorecard/v1/schools?&_fields=admissions.sat_scores.average.overall,school.name,repayment.repayment_cohort.3_year_declining_balance&per_page=100&page=40&api_key=4JJj7qqqCjEBcUklTsF6XI2X5ZK69KZAZ1P8QKjZ")
json_data=data.json()
json_data
# Out:
# {'metadata': {'page': 40, 'total': 6543, 'per_page': 100},
#  'results': [{'school.name': 'ASA College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Ohio State School of Cosmetology-Heath',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Yeshivas Novominsk',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Southern Careers Institute-Corpus Christi',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Rabbinical College of Ohr Shimon Yisroel',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Carroll Community College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Galen College of Nursing-Tampa Bay',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Galen College of Nursing-San Antonio',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Sarasota School of Massage Therapy',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Schuyler Steuben Chemung Tioga Allegany BOCES',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Delaware Chenango Madison Otsego BOCES-Practical Nursing Program',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Central Susquehanna Intermediate Unit LPN Career',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Myotherapy College of Utah',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'City College-Gainesville',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'G Skin & Beauty Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Cosmetology Training Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Stage One-The Hair School',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Empire Beauty School-Malden',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Xenon International Academy-Omaha',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Capri Institute of Hair Design-Brick',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Capri Institute of Hair Design-Kenilworth',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Capri Institute of Hair Design-Paramus',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Orlo School of Hair Design and Cosmetology',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Eastland-Fairfield Career and Technical Schools',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Empire Beauty School-Cincinnati',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Mahoning County Career and Technical Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Pickaway Ross Joint Vocational School District',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Pioneer Career and Technology Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': "Raphael's School of Beauty Culture Inc-Boardman",
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Scioto County Career Technical Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Trumbull Career & Technical Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Pacific Bible College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Lake Erie College of Osteopathic Medicine',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'UCAS University of Cosmetology Arts & Sciences-Harlingen',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Highlights Beauty Schools',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Empire Beauty School-Green Bay',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Warren County Career Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Paul Mitchell the School-Wichita',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Pinnacle Institute of Cosmetology',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Southern Careers Institute-Pharr',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Laurel Technical Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Florida National University-Main Campus',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Georgia Institute of Cosmetology',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Nouvelle Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Franklin Technology Center Adult Education',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Professional Technical Institution',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Erikson Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'South Texas College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Pike County Joint Vocational School District',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Lorain County Joint Vocational School District',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Roger Williams University School of Law',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'California State University-Monterey Bay',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Ohio Media School-Valley View',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'EINE Inc',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Marian Health Careers Center-Los Angeles Campus',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Cleveland Clinic Health System-School of Diagnostic Imaging',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Academy for Nursing and Health Occupations',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Shawsheen Valley School of Practical Nursing',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Shear Ego International School of Hair Design',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Remington College-Memphis Campus',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Fayette Institute of Technology',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Capella University',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'College of Menominee Nation',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Leech Lake Tribal College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Spartan College of Aeronautics & Technology',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Stone Academy-Waterbury',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Yukon Beauty College Inc',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'United Education Institute-Morrow',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Toni & Guy Hairdressing Academy-Atlanta',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Mitchells Academy',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Artistic Academy of Hair Design',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Motoring Technical Training Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Mech-Tech College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Baldwin Beauty School-North Austin',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Jean Madeline Aveda Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Pacific College of Health and Science',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Tricoci University of Beauty Culture-Indianapolis',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Trine University-Regional/Non-Traditional Campuses',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Pennsylvania Highlands Community College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Nevada Career Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Phillips Theological Seminary',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Empire Beauty School-Hanover',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Industrial Management Training Institute',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Allen School-Jamaica',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Premiere Career College',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'The University of Texas MD Anderson Cancer Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Paul Mitchell the School-Huntsville',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Cedars Sinai Medical Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Estes Institute of Cosmetology Arts and Science',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Baldwin Park Adult & Community Education',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Ventura Adult and Continuing Education',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'CT Aerotech',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Stratford School for Aviation Maintenance Technicians',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'City College-Altamonte Springs',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Career Center of Southern Illinois',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Crave Beauty Academy',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Hastings Beauty School',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Kirksville Area Technical Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'South Central Career Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None},
#   {'school.name': 'Saline County Career Center',
#    'admissions.sat_scores.average.overall': None,
#    'repayment.repayment_cohort.3_year_declining_balance': None}]}

# %%
metadata = json_data["metadata"]
total = metadata["total"]
per_page = metadata["per_page"]
num_of_pages = total / per_page
num_of_pages
# Out:
# 65.43

# %%
merged2021_22 = pd.read_csv("data/MERGED2021_22_PP.csv",dtype="string",index_col = 0)
merged2021_22
# Out:
#              OPEID  OPEID6                                             INSTNM  \
# UNITID
# 100654    00100200  001002                           Alabama A & M University
# 100663    00105200  001052                University of Alabama at Birmingham
# 100690    02503400  025034                                 Amridge University
# 100706    00105500  001055                University of Alabama in Huntsville
# 100724    00100500  001005                           Alabama State University
# ...            ...     ...                                                ...
# 49576720  00332918  003329      Pennsylvania State University-Penn State York
# 49576721  00332919  003329  Pennsylvania State University-Penn State Great...
# 49576722  00332920  003329  Pennsylvania State University-Penn State Harri...
# 49576723  00332921  003329  Pennsylvania State University-Penn State Brand...
# 49664501  04285601  042856  Burlington County Institute of Technology - Ad...
#
#                 CITY STABBR         ZIP  \
# UNITID
# 100654        Normal     AL       35762
# 100663    Birmingham     AL  35294-0110
# 100690    Montgomery     AL  36117-3553
# 100706    Huntsville     AL       35899
# 100724    Montgomery     AL  36104-0271
# ...              ...    ...         ...
# 49576720        York     PA  17403-3326
# 49576721     Malvern     PA  19355-1488
# 49576722  Middletown     PA  17057-4846
# 49576723       Media     PA  19063-5522
# 49664501     Medford     NJ   080550000
#
#                                                ACCREDAGENCY  \
# UNITID
# 100654    Southern Association of Colleges and Schools C...
# 100663    Southern Association of Colleges and Schools C...
# 100690    Southern Association of Colleges and Schools C...
# 100706    Southern Association of Colleges and Schools C...
# 100724    Southern Association of Colleges and Schools C...
# ...                                                     ...
# 49576720       Middle States Commission on Higher Education
# 49576721       Middle States Commission on Higher Education
# 49576722       Middle States Commission on Higher Education
# 49576723       Middle States Commission on Higher Education
# 49664501    Middle States Commission on Secondary Education
#
#                                      INSTURL  \
# UNITID
# 100654                         www.aamu.edu/
# 100663                  https://www.uab.edu/
# 100690    https://www.amridgeuniversity.edu/
# 100706                          www.uah.edu/
# 100724                        www.alasu.edu/
# ...                                      ...
# 49576720                       york.psu.edu/
# 49576721                greatvalley.psu.edu/
# 49576722                 harrisburg.psu.edu/
# 49576723                 brandywine.psu.edu/
# 49664501     https://www.bcit.cc/bcitadulted
#
#                                                      NPCURL SCH_DEG  ...  \
# UNITID                                                               ...
# 100654    www.aamu.edu/admissions-aid/tuition-fees/net-p...    <NA>  ...
# 100663    https://tcc.ruffalonl.com/University of Alabam...    <NA>  ...
# 100690             https://www2.amridgeuniversity.edu:9091/    <NA>  ...
# 100706                                      finaid.uah.edu/    <NA>  ...
# 100724    www.alasu.edu/cost-aid/tuition-costs/net-price...    <NA>  ...
# ...                                                     ...     ...  ...
# 49576720                                               <NA>    <NA>  ...
# 49576721                                               <NA>    <NA>  ...
# 49576722                                               <NA>    <NA>  ...
# 49576723                                               <NA>    <NA>  ...
# 49664501                                               <NA>    <NA>  ...
#
#          BBRR4_PP_MALE_DISCHARGE  BBRR4_PP_NOMALE_N BBRR4_PP_NOMALE_DFLT  \
# UNITID
# 100654         PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 100663         PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 100690         PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 100706         PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 100724         PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# ...                          ...                ...                  ...
# 49576720       PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 49576721       PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 49576722       PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 49576723       PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
# 49664501       PrivacySuppressed  PrivacySuppressed    PrivacySuppressed
#
#          BBRR4_PP_NOMALE_DLNQ BBRR4_PP_NOMALE_FBR BBRR4_PP_NOMALE_DFR  \
# UNITID
# 100654      PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 100663      PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 100690      PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 100706      PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 100724      PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# ...                       ...                 ...                 ...
# 49576720    PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 49576721    PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 49576722    PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 49576723    PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
# 49664501    PrivacySuppressed   PrivacySuppressed   PrivacySuppressed
#
#          BBRR4_PP_NOMALE_NOPROG BBRR4_PP_NOMALE_MAKEPROG  \
# UNITID
# 100654        PrivacySuppressed        PrivacySuppressed
# 100663        PrivacySuppressed        PrivacySuppressed
# 100690        PrivacySuppressed        PrivacySuppressed
# 100706        PrivacySuppressed        PrivacySuppressed
# 100724        PrivacySuppressed        PrivacySuppressed
# ...                         ...                      ...
# 49576720      PrivacySuppressed        PrivacySuppressed
# 49576721      PrivacySuppressed        PrivacySuppressed
# 49576722      PrivacySuppressed        PrivacySuppressed
# 49576723      PrivacySuppressed        PrivacySuppressed
# 49664501      PrivacySuppressed        PrivacySuppressed
#
#          BBRR4_PP_NOMALE_PAIDINFULL BBRR4_PP_NOMALE_DISCHARGE
# UNITID
# 100654            PrivacySuppressed         PrivacySuppressed
# 100663            PrivacySuppressed         PrivacySuppressed
# 100690            PrivacySuppressed         PrivacySuppressed
# 100706            PrivacySuppressed         PrivacySuppressed
# 100724            PrivacySuppressed         PrivacySuppressed
# ...                             ...                       ...
# 49576720          PrivacySuppressed         PrivacySuppressed
# 49576721          PrivacySuppressed         PrivacySuppressed
# 49576722          PrivacySuppressed         PrivacySuppressed
# 49576723          PrivacySuppressed         PrivacySuppressed
# 49664501          PrivacySuppressed         PrivacySuppressed
#
# [6543 rows x 3213 columns]
